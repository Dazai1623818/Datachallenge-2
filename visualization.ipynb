# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
path = open('document.txt', 'r').read().strip()
df_data = pd.read_feather(f"{path}/{2019}_street.feather")

# %%
counts = df_data['Crime type'].value_counts()
counts = counts.to_frame()
counts.reset_index(inplace=True)
counts
# Out:
#                            index  Crime type
# 0   Violence and sexual offences     1883205
# 1          Anti-social behaviour     1311848
# 2      Criminal damage and arson      549655
# 3                    Other theft      520104
# 4                  Vehicle crime      447553
# 5                   Public order      436909
# 6                       Burglary      384606
# 7                    Shoplifting      359312
# 8                          Drugs      175808
# 9          Theft from the person      110894
# 10                   Other crime      103584
# 11                 Bicycle theft       88126
# 12                       Robbery       87075
# 13         Possession of weapons       46923

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(data=counts, x='index', y='Crime type', palette="Blues_d", ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);
